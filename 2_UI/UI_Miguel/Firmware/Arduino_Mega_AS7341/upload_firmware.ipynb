# %% [markdown]
# # Carga de firmware

# %%
# !python -m serial.tools.list_ports
# Out:
# COM12
# COM13
# COM16
# 3 ports found

# %%
# !arduino-cli.exe
# Out:
# Interfaz de la línea de comandos de Arduino (arduino-cli).
#
# Uso:
#   arduino-cli [command]
#
# Ejemplos:
#   arduino-cli.exe <comando> [banderas...]
#
# Comandos disponibles:
#   board           Comandos de la placa Arduino.
#   burn-bootloader Cargar el bootloader.
#   cache           Comandos de cache de Arduino
#   compile         Compila los sketch de Arduino
#   completion      Generates completion scripts
#   config          Commandos de configuración de Arduino
#   core            Operaciones del núcleo Arduino
#   daemon          Run the Arduino CLI as a gRPC daemon.
#   debug           Depurar sketches de Arduino.
#   help            Help about any command
#   lib             Comandos sobre librerías de Arduino
#   monitor         Abre un puerto de comunicación con una placa.
#   outdated        Lists cores and libraries that can be upgraded
#   profile         Build profile operations.
#   sketch          Comandos de sketch de Arduino CLI.
# ...

# %%
# !arduino-cli board list
# Out:
# Puerto Protocolo Tipo              Nombre de la placa FQBN Núcleo
# COM12  serial    Serial Port       Unknown
# COM13  serial    Serial Port       Unknown
# COM16  serial    Serial Port (USB) Unknown

# %%
# !dir
# Out:
#  El volumen de la unidad D no tiene etiqueta.
#  El n�mero de serie del volumen es: 08C4-45BE
#
#  Directorio de d:\DOCUMENTOS\PROJECTS\Fluorimetro_lowcost\2_UI\UI_Miguel\Firmware\Arduino_Mega_AS7341
#
# 16/09/2026  03:36 p.m.    <DIR>          .
# 15/09/2026  02:08 p.m.    <DIR>          ..
# 16/09/2026  03:36 p.m.        37,865,984 arduino-cli.exe
# 16/09/2026  03:01 p.m.                97 main.py
# 16/09/2026  03:03 p.m.               275 pyproject.toml
# 15/09/2026  02:08 p.m.               923 README.md
# 16/09/2026  03:43 p.m.             5,407 upload_firmware.ipynb
# 15/09/2026  02:08 p.m.    <DIR>          v1.0
#                5 archivos     37,872,686 bytes
#                3 dirs  436,163,256,320 bytes libres

# %%
# !arduino-cli.exe upload -p COM16 --fqbn arduino:avr:mega --input-file ./v1.0/firmware/hex_files/firmware1.hex
# Out:
# New upload port: COM16 (serial)
